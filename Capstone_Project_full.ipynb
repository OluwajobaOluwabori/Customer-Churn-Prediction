# %% [markdown]
# <a href="https://colab.research.google.com/github/OluwajobaOluwabori/Customer-Churn-Prediction/blob/main/Capstone_Project_full.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install the dependencies

# %%
'''
Installing Apache Spark 3.3.24 with hadoop 3.0, Java 8 and Findspark in order to locate the spark in the system.
'''

# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://dlcdn.apache.org/spark/spark-3.3.4/spark-3.3.4-bin-hadoop3.tgz -O spark-3.3.4-bin-hadoop3.tgz
# !tar -xvzf /content/spark-3.3.4-bin-hadoop3.tgz
# !pip install -q findspark
# Out:
# spark-3.3.4-bin-hadoop3/
# spark-3.3.4-bin-hadoop3/R/
# spark-3.3.4-bin-hadoop3/R/lib/
# spark-3.3.4-bin-hadoop3/R/lib/sparkr.zip
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/worker/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/worker/worker.R
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/worker/daemon.R
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/tests/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/tests/testthat/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/tests/testthat/test_basic.R
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/profile/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/profile/shell.R
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/profile/general.R
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/doc/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.html
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.Rmd
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.R
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/doc/index.html
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/R/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/R/SparkR
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/R/SparkR.rdx
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/R/SparkR.rdb
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/Meta/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/Meta/features.rds
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/Meta/package.rds
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/Meta/links.rds
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/Meta/hsearch.rds
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/Meta/nsInfo.rds
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/Meta/vignette.rds
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/Meta/Rd.rds
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/DESCRIPTION
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/NAMESPACE
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/INDEX
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/html/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/html/R.css
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/html/00Index.html
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/help/
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/help/aliases.rds
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/help/AnIndex
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/help/SparkR.rdx
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/help/SparkR.rdb
# spark-3.3.4-bin-hadoop3/R/lib/SparkR/help/paths.rds
# spark-3.3.4-bin-hadoop3/sbin/
# spark-3.3.4-bin-hadoop3/sbin/stop-mesos-shuffle-service.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-mesos-dispatcher.sh
# spark-3.3.4-bin-hadoop3/sbin/start-mesos-shuffle-service.sh
# spark-3.3.4-bin-hadoop3/sbin/start-mesos-dispatcher.sh
# spark-3.3.4-bin-hadoop3/sbin/spark-config.sh
# spark-3.3.4-bin-hadoop3/sbin/workers.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-workers.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-worker.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-thriftserver.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-slaves.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-slave.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-master.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-history-server.sh
# spark-3.3.4-bin-hadoop3/sbin/stop-all.sh
# spark-3.3.4-bin-hadoop3/sbin/start-workers.sh
# spark-3.3.4-bin-hadoop3/sbin/start-worker.sh
# spark-3.3.4-bin-hadoop3/sbin/start-thriftserver.sh
# spark-3.3.4-bin-hadoop3/sbin/start-slaves.sh
# spark-3.3.4-bin-hadoop3/sbin/start-slave.sh
# spark-3.3.4-bin-hadoop3/sbin/start-master.sh
# spark-3.3.4-bin-hadoop3/sbin/start-history-server.sh
# spark-3.3.4-bin-hadoop3/sbin/start-all.sh
# spark-3.3.4-bin-hadoop3/sbin/spark-daemons.sh
# spark-3.3.4-bin-hadoop3/sbin/spark-daemon.sh
# spark-3.3.4-bin-hadoop3/sbin/slaves.sh
# spark-3.3.4-bin-hadoop3/sbin/decommission-worker.sh
# spark-3.3.4-bin-hadoop3/sbin/decommission-slave.sh
# spark-3.3.4-bin-hadoop3/python/
# spark-3.3.4-bin-hadoop3/python/pyspark/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/_typing.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/usage_logging/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/usage_logging/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/usage_logging/usage_logger.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/typedef/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/typedef/typehints.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/typedef/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_window.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_typedef.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_stats.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_sql.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_spark_functions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_series_string.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_series_datetime.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_series_conversion.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_series.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_rolling.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_reshape.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_repr.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames_groupby_rolling.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames_groupby_expanding.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames_groupby.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_numpy_compat.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_namespace.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_internal.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_indexops_spark.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_indexing.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_groupby.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_frame_spark.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_extension.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_expanding.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_default_index.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe_spark_io.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe_conversion.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_csv.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_config.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/test_categorical.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/plot/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/plot/test_series_plot_plotly.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/plot/test_series_plot_matplotlib.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/plot/test_series_plot.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/plot/test_frame_plot_plotly.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/plot/test_frame_plot_matplotlib.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/plot/test_frame_plot.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/plot/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/indexes/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_timedelta.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_datetime.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_category.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_base.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/indexes/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/testing_utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_udt_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_timedelta_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_string_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_num_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_null_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_datetime_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_date_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_complex_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_categorical_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_boolean_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_binary_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_base.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/tests/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/spark/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/spark/functions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/spark/accessors.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/spark/utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/spark/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/plot/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/plot/plotly.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/plot/matplotlib.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/plot/core.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/plot/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/window.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/series.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/indexes.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/groupby.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/general_functions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/frame.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/common.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/missing/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexes/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexes/timedelta.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexes/numeric.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexes/multi.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexes/datetimes.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexes/category.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexes/base.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexes/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/timedelta_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/string_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/num_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/null_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/datetime_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/date_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/categorical_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/boolean_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/binary_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/base.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/udt_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/complex_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/data_type_ops/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/window.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/strings.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/sql_processor.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/sql_formatter.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/series.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/numpy_compat.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/namespace.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/mlflow.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/ml.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/internal.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/indexing.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/groupby.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/generic.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/frame.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/extensions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/exceptions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/datetimes.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/config.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/categorical.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/base.py
# spark-3.3.4-bin-hadoop3/python/pyspark/pandas/accessors.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/util.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tree.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/regression.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/recommendation.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/recommendation.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/random.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/random.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/feature.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/evaluation.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/clustering.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/classification.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/_typing.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tests/
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tests/test_util.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tests/test_streaming_algorithms.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tests/test_stat.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tests/test_linalg.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tests/test_feature.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tests/test_algorithms.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/tests/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/stat/
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/stat/_statistics.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/stat/test.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/stat/distribution.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/stat/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/stat/KernelDensity.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/linalg/
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/linalg/distributed.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/linalg/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/fpm.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/common.py
# spark-3.3.4-bin-hadoop3/python/pyspark/mllib/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/wrapper.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/util.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tuning.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tree.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/stat.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/regression.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/recommendation.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/image.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/functions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/fpm.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/feature.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/evaluation.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/common.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/clustering.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/classification.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/base.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/_typing.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_wrapper.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_util.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_tuning.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_training_summary.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_stat.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_pipeline.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_persistence.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_param.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_linalg.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_image.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_feature.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_evaluation.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_base.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/test_algorithms.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/typing/
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/typing/test_evaluation.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/typing/test_clustering.yaml
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/typing/test_regression.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/typing/test_readable.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/typing/test_param.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/typing/test_feature.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/typing/test_classification.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/tests/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/pipeline.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/param/
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/param/shared.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/param/_shared_params_code_gen.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/param/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/linalg/
# spark-3.3.4-bin-hadoop3/python/pyspark/ml/linalg/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/cloudpickle/
# spark-3.3.4-bin-hadoop3/python/pyspark/cloudpickle/compat.py
# spark-3.3.4-bin-hadoop3/python/pyspark/cloudpickle/cloudpickle_fast.py
# spark-3.3.4-bin-hadoop3/python/pyspark/cloudpickle/cloudpickle.py
# spark-3.3.4-bin-hadoop3/python/pyspark/cloudpickle/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/_typing.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/_globals.py
# spark-3.3.4-bin-hadoop3/python/pyspark/traceback_utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_worker.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_util.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_taskcontext.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_statcounter.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_shuffle.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_serializers.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_readwrite.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_rddbarrier.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_rdd.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_profiler.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_pin_thread.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_join.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_install_spark.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_daemon.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_context.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_conf.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_broadcast.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/test_appsubmit.py
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/typing/
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/typing/test_rdd.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/typing/test_resultiterable.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/typing/test_core.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/typing/test_context.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/tests/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/testing/
# spark-3.3.4-bin-hadoop3/python/pyspark/testing/utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/testing/streamingutils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/testing/sqlutils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/testing/pandasutils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/testing/mlutils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/testing/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/testing/mllibutils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/kinesis.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/dstream.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/context.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/util.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/tests/
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/tests/test_listener.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/tests/test_kinesis.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/tests/test_dstream.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/tests/test_context.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/tests/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/listener.py
# spark-3.3.4-bin-hadoop3/python/pyspark/streaming/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/status.py
# spark-3.3.4-bin-hadoop3/python/pyspark/statcounter.py
# spark-3.3.4-bin-hadoop3/python/pyspark/__pycache__/
# spark-3.3.4-bin-hadoop3/python/pyspark/__pycache__/install.cpython-38.pyc
# spark-3.3.4-bin-hadoop3/python/pyspark/python/
# spark-3.3.4-bin-hadoop3/python/pyspark/python/pyspark/
# spark-3.3.4-bin-hadoop3/python/pyspark/python/pyspark/shell.py
# spark-3.3.4-bin-hadoop3/python/pyspark/shuffle.py
# spark-3.3.4-bin-hadoop3/python/pyspark/shell.py
# spark-3.3.4-bin-hadoop3/python/pyspark/serializers.py
# spark-3.3.4-bin-hadoop3/python/pyspark/rdd.py
# spark-3.3.4-bin-hadoop3/python/pyspark/profiler.py
# spark-3.3.4-bin-hadoop3/python/pyspark/worker.py
# spark-3.3.4-bin-hadoop3/python/pyspark/version.py
# spark-3.3.4-bin-hadoop3/python/pyspark/util.py
# spark-3.3.4-bin-hadoop3/python/pyspark/taskcontext.py
# spark-3.3.4-bin-hadoop3/python/pyspark/storagelevel.py
# spark-3.3.4-bin-hadoop3/python/pyspark/join.py
# spark-3.3.4-bin-hadoop3/python/pyspark/java_gateway.py
# spark-3.3.4-bin-hadoop3/python/pyspark/instrumentation_utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/install.py
# spark-3.3.4-bin-hadoop3/python/pyspark/find_spark_home.py
# spark-3.3.4-bin-hadoop3/python/pyspark/files.py
# spark-3.3.4-bin-hadoop3/python/pyspark/daemon.py
# spark-3.3.4-bin-hadoop3/python/pyspark/context.py
# spark-3.3.4-bin-hadoop3/python/pyspark/conf.py
# spark-3.3.4-bin-hadoop3/python/pyspark/broadcast.py
# spark-3.3.4-bin-hadoop3/python/pyspark/accumulators.py
# spark-3.3.4-bin-hadoop3/python/pyspark/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/streaming.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/sql_formatter.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/session.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/readwriter.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/observation.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/group.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/functions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/dataframe.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/context.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/conf.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/column.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/catalog.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/_typing.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/window.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/udf.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/types.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/avro/
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/avro/functions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/avro/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_readwriter.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_udf_window.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_udf_typehints_with_future_annotations.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_udf_typehints.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_udf_scalar.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_udf_grouped_agg.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_udf.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_map.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_grouped_map.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_pandas_cogrouped_map.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_group.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_functions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_datasources.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_dataframe.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_context.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_conf.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_column.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_catalog.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_arrow_map.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_arrow.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_udf.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_types.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_streaming.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_session.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_serde.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/typing/
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/typing/test_session.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/typing/test_functions.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/typing/test_dataframe.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/typing/test_udf.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/typing/test_readwriter.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/typing/test_column.yml
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/test_udf_profiler.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/tests/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/utils.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/types.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/typehints.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/serializers.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/map_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/group_ops.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/functions.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/conversion.py
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/functions.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/_typing/
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/_typing/__init__.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/series.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/frame.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/__init__.pyi
# spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/resultiterable.py
# spark-3.3.4-bin-hadoop3/python/pyspark/resource/
# spark-3.3.4-bin-hadoop3/python/pyspark/resource/requests.py
# spark-3.3.4-bin-hadoop3/python/pyspark/resource/profile.py
# spark-3.3.4-bin-hadoop3/python/pyspark/resource/information.py
# spark-3.3.4-bin-hadoop3/python/pyspark/resource/tests/
# spark-3.3.4-bin-hadoop3/python/pyspark/resource/tests/test_resources.py
# spark-3.3.4-bin-hadoop3/python/pyspark/resource/tests/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/resource/__init__.py
# spark-3.3.4-bin-hadoop3/python/pyspark/rddsampler.py
# spark-3.3.4-bin-hadoop3/python/pyspark/py.typed
# spark-3.3.4-bin-hadoop3/python/lib/
# spark-3.3.4-bin-hadoop3/python/lib/pyspark.zip
# spark-3.3.4-bin-hadoop3/python/lib/py4j-0.10.9.5-src.zip
# spark-3.3.4-bin-hadoop3/python/lib/PY4J_LICENSE.txt
# spark-3.3.4-bin-hadoop3/python/test_support/
# spark-3.3.4-bin-hadoop3/python/test_support/userlibrary.py
# spark-3.3.4-bin-hadoop3/python/test_support/userlib-0.1.zip
# spark-3.3.4-bin-hadoop3/python/test_support/sql/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=9/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/part-r-00007.gz.parquet
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/.part-r-00007.gz.parquet.crc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/part-r-00005.gz.parquet
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/.part-r-00005.gz.parquet.crc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/part-r-00004.gz.parquet
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/part-r-00002.gz.parquet
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/.part-r-00004.gz.parquet.crc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/.part-r-00002.gz.parquet.crc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2014/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2014/month=9/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/part-r-00008.gz.parquet
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/.part-r-00008.gz.parquet.crc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/_metadata
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/_common_metadata
# spark-3.3.4-bin-hadoop3/python/test_support/sql/parquet_partitioned/_SUCCESS
# spark-3.3.4-bin-hadoop3/python/test_support/sql/ages.csv
# spark-3.3.4-bin-hadoop3/python/test_support/sql/text-test.txt
# spark-3.3.4-bin-hadoop3/python/test_support/sql/streaming/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/streaming/text-test.txt
# spark-3.3.4-bin-hadoop3/python/test_support/sql/people_array_utf16le.json
# spark-3.3.4-bin-hadoop3/python/test_support/sql/people_array.json
# spark-3.3.4-bin-hadoop3/python/test_support/sql/people1.json
# spark-3.3.4-bin-hadoop3/python/test_support/sql/people.json
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.3.4-bin-hadoop3/python/test_support/sql/orc_partitioned/_SUCCESS
# spark-3.3.4-bin-hadoop3/python/test_support/sql/ages_newlines.csv
# spark-3.3.4-bin-hadoop3/python/test_support/hello/
# spark-3.3.4-bin-hadoop3/python/test_support/hello/sub_hello/
# spark-3.3.4-bin-hadoop3/python/test_support/hello/sub_hello/sub_hello.txt
# spark-3.3.4-bin-hadoop3/python/test_support/hello/hello.txt
# spark-3.3.4-bin-hadoop3/python/test_support/SimpleHTTPServer.py
# spark-3.3.4-bin-hadoop3/python/test_coverage/
# spark-3.3.4-bin-hadoop3/python/test_coverage/sitecustomize.py
# spark-3.3.4-bin-hadoop3/python/test_coverage/coverage_daemon.py
# spark-3.3.4-bin-hadoop3/python/test_coverage/conf/
# spark-3.3.4-bin-hadoop3/python/test_coverage/conf/spark-defaults.conf
# spark-3.3.4-bin-hadoop3/python/docs/
# spark-3.3.4-bin-hadoop3/python/docs/make2.bat
# spark-3.3.4-bin-hadoop3/python/docs/Makefile
# spark-3.3.4-bin-hadoop3/python/docs/source/
# spark-3.3.4-bin-hadoop3/python/docs/source/conf.py
# spark-3.3.4-bin-hadoop3/python/docs/source/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/python_packaging.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/sql/
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/sql/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/sql/arrow_pandas.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/types.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/typehints.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/transform_apply.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/supported_pandas_api.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/options.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/faq.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/best_practices.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/pandas_pyspark.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/from_to_dbms.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/user_guide/arrow_pandas.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.streaming.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.ml.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.ss/
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.ss/query_management.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.ss/core_classes.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.ss/io.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.ss/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/spark_session.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/io.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/grouping.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/functions.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/dataframe.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/data_types.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/core_classes.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/column.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/catalog.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/window.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/row.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/observation.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/configuration.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.sql/avro.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.resource.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/window.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/series.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/io.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/indexing.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/groupby.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/general_functions.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/frame.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/ml.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.pandas/extensions.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/reference/pyspark.mllib.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/pyspark_3.2_to_3.3.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/pyspark_3.1_to_3.2.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/pyspark_2.4_to_3.0.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/pyspark_2.3_to_2.4.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/pyspark_2.3.0_to_2.3.1_above.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/pyspark_2.2_to_2.3.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/pyspark_1.4_to_1.5.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/pyspark_1.0_1.2_to_1.3.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/koalas_to_pyspark.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/migration_guide/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/getting_started/
# spark-3.3.4-bin-hadoop3/python/docs/source/getting_started/quickstart_ps.ipynb
# spark-3.3.4-bin-hadoop3/python/docs/source/getting_started/quickstart_df.ipynb
# spark-3.3.4-bin-hadoop3/python/docs/source/getting_started/install.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/getting_started/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/development/
# spark-3.3.4-bin-hadoop3/python/docs/source/development/testing.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/development/index.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/development/debugging.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/development/contributing.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/development/setting_ide.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/_templates/
# spark-3.3.4-bin-hadoop3/python/docs/source/_templates/autosummary/
# spark-3.3.4-bin-hadoop3/python/docs/source/_templates/autosummary/class_with_docs.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/_templates/autosummary/class.rst
# spark-3.3.4-bin-hadoop3/python/docs/source/_static/
# spark-3.3.4-bin-hadoop3/python/docs/source/_static/css/
# spark-3.3.4-bin-hadoop3/python/docs/source/_static/css/pyspark.css
# spark-3.3.4-bin-hadoop3/python/docs/make.bat
# spark-3.3.4-bin-hadoop3/python/MANIFEST.in
# spark-3.3.4-bin-hadoop3/python/.gitignore
# spark-3.3.4-bin-hadoop3/python/.coveragerc
# spark-3.3.4-bin-hadoop3/python/dist/
# spark-3.3.4-bin-hadoop3/python/pyspark.egg-info/
# spark-3.3.4-bin-hadoop3/python/pyspark.egg-info/SOURCES.txt
# spark-3.3.4-bin-hadoop3/python/pyspark.egg-info/top_level.txt
# spark-3.3.4-bin-hadoop3/python/pyspark.egg-info/requires.txt
# spark-3.3.4-bin-hadoop3/python/pyspark.egg-info/dependency_links.txt
# spark-3.3.4-bin-hadoop3/python/pyspark.egg-info/PKG-INFO
# spark-3.3.4-bin-hadoop3/python/README.md
# spark-3.3.4-bin-hadoop3/python/setup.py
# spark-3.3.4-bin-hadoop3/python/setup.cfg
# spark-3.3.4-bin-hadoop3/python/run-tests.py
# spark-3.3.4-bin-hadoop3/python/run-tests-with-coverage
# spark-3.3.4-bin-hadoop3/python/run-tests
# spark-3.3.4-bin-hadoop3/python/mypy.ini
# spark-3.3.4-bin-hadoop3/bin/
# spark-3.3.4-bin-hadoop3/bin/sparkR
# spark-3.3.4-bin-hadoop3/bin/spark-class2.cmd
# spark-3.3.4-bin-hadoop3/bin/spark-class
# spark-3.3.4-bin-hadoop3/bin/pyspark2.cmd
# spark-3.3.4-bin-hadoop3/bin/pyspark
# spark-3.3.4-bin-hadoop3/bin/load-spark-env.sh
# spark-3.3.4-bin-hadoop3/bin/load-spark-env.cmd
# spark-3.3.4-bin-hadoop3/bin/docker-image-tool.sh
# spark-3.3.4-bin-hadoop3/bin/sparkR2.cmd
# spark-3.3.4-bin-hadoop3/bin/sparkR.cmd
# spark-3.3.4-bin-hadoop3/bin/spark-submit2.cmd
# spark-3.3.4-bin-hadoop3/bin/spark-submit.cmd
# spark-3.3.4-bin-hadoop3/bin/spark-submit
# spark-3.3.4-bin-hadoop3/bin/spark-sql2.cmd
# spark-3.3.4-bin-hadoop3/bin/spark-sql.cmd
# spark-3.3.4-bin-hadoop3/bin/spark-sql
# spark-3.3.4-bin-hadoop3/bin/spark-shell2.cmd
# spark-3.3.4-bin-hadoop3/bin/spark-shell.cmd
# spark-3.3.4-bin-hadoop3/bin/spark-shell
# spark-3.3.4-bin-hadoop3/bin/spark-class.cmd
# spark-3.3.4-bin-hadoop3/bin/run-example.cmd
# spark-3.3.4-bin-hadoop3/bin/run-example
# spark-3.3.4-bin-hadoop3/bin/pyspark.cmd
# spark-3.3.4-bin-hadoop3/bin/find-spark-home.cmd
# spark-3.3.4-bin-hadoop3/bin/find-spark-home
# spark-3.3.4-bin-hadoop3/bin/beeline.cmd
# spark-3.3.4-bin-hadoop3/bin/beeline
# spark-3.3.4-bin-hadoop3/README.md
# spark-3.3.4-bin-hadoop3/conf/
# spark-3.3.4-bin-hadoop3/conf/workers.template
# spark-3.3.4-bin-hadoop3/conf/spark-env.sh.template
# spark-3.3.4-bin-hadoop3/conf/spark-defaults.conf.template
# spark-3.3.4-bin-hadoop3/conf/metrics.properties.template
# spark-3.3.4-bin-hadoop3/conf/log4j2.properties.template
# spark-3.3.4-bin-hadoop3/conf/fairscheduler.xml.template
# spark-3.3.4-bin-hadoop3/data/
# spark-3.3.4-bin-hadoop3/data/streaming/
# spark-3.3.4-bin-hadoop3/data/streaming/AFINN-111.txt
# spark-3.3.4-bin-hadoop3/data/mllib/
# spark-3.3.4-bin-hadoop3/data/mllib/streaming_kmeans_data_test.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_svm_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_multiclass_classification_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_movielens_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_linear_regression_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_libsvm_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_lda_libsvm_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_lda_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_kmeans_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_isotonic_regression_libsvm_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_fpgrowth.txt
# spark-3.3.4-bin-hadoop3/data/mllib/sample_binary_classification_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/ridge-data/
# spark-3.3.4-bin-hadoop3/data/mllib/ridge-data/lpsa.data
# spark-3.3.4-bin-hadoop3/data/mllib/pic_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/pagerank_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/kmeans_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/images/
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/multi-channel/
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/multi-channel/grayscale.jpg
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/multi-channel/chr30.4.184.jpg
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/multi-channel/BGRA_alpha_60.png
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/multi-channel/BGRA.png
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/license.txt
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/kittens/
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/kittens/not-image.txt
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/kittens/DP802813.jpg
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/kittens/DP153539.jpg
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/kittens/54893.jpg
# spark-3.3.4-bin-hadoop3/data/mllib/images/origin/kittens/29.5.a_b_EGDP022204.jpg
# spark-3.3.4-bin-hadoop3/data/mllib/images/license.txt
# spark-3.3.4-bin-hadoop3/data/mllib/gmm_data.txt
# spark-3.3.4-bin-hadoop3/data/mllib/als/
# spark-3.3.4-bin-hadoop3/data/mllib/als/test.data
# spark-3.3.4-bin-hadoop3/data/mllib/als/sample_movielens_ratings.txt
# spark-3.3.4-bin-hadoop3/data/graphx/
# spark-3.3.4-bin-hadoop3/data/graphx/users.txt
# spark-3.3.4-bin-hadoop3/data/graphx/followers.txt
# spark-3.3.4-bin-hadoop3/NOTICE
# spark-3.3.4-bin-hadoop3/licenses/
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-graphlib-dot.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-f2j.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-dnsjava.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-dagre-d3.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-cloudpickle.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-bootstrap.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-blas.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-automaton.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-arpack.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-antlr.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-JTransforms.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-JLargeArrays.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-CC0.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-AnchorJS.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-vis-timeline.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-scala.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-protobuf.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-netlib.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-datatables.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-d3.min.js.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-zstd.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-zstd-jni.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-xmlenc.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-spire.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-sorttable.js.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-slf4j.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-scopt.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-sbt-launch-lib.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-respond.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-reflectasm.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-re2j.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-pyrolite.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-py4j.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-pmml-model.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-paranamer.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-mustache.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-modernizr.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-minlog.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-matchMedia-polyfill.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-machinist.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-leveldbjni.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-kryo.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jsp-api.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-json-formatter.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jquery.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-join.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jodd.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jline.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jaxb-runtime.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-javolution.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-javax-transaction-transaction-api.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-javassist.html
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-janino.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jakarta.xml.bind-api.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jakarta.activation-api.txt
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jakarta-ws-rs-api
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-jakarta-annotation-api
# spark-3.3.4-bin-hadoop3/licenses/LICENSE-istack-commons-runtime.txt
# spark-3.3.4-bin-hadoop3/LICENSE
# spark-3.3.4-bin-hadoop3/examples/
# spark-3.3.4-bin-hadoop3/examples/src/
# spark-3.3.4-bin-hadoop3/examples/src/main/
# ...
# spark-3.3.4-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/hive/
# spark-3.3.4-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/hive/JavaSparkHiveExample.java
# spark-3.3.4-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedScalar.java
# spark-3.3.4-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/sql/JavaSparkSQLExample.java
# spark-3.3.4-bin-hadoop3/examples/src/main/scripts/
# spark-3.3.4-bin-hadoop3/examples/src/main/scripts/getGpusResources.sh
# spark-3.3.4-bin-hadoop3/examples/jars/
# spark-3.3.4-bin-hadoop3/examples/jars/spark-examples_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/examples/jars/scopt_2.12-3.7.1.jar
# spark-3.3.4-bin-hadoop3/kubernetes/
# spark-3.3.4-bin-hadoop3/kubernetes/tests/
# spark-3.3.4-bin-hadoop3/kubernetes/tests/worker_memory_check.py
# spark-3.3.4-bin-hadoop3/kubernetes/tests/python_executable_check.py
# spark-3.3.4-bin-hadoop3/kubernetes/tests/pyfiles.py
# spark-3.3.4-bin-hadoop3/kubernetes/tests/py_container_checks.py
# spark-3.3.4-bin-hadoop3/kubernetes/tests/decommissioning_cleanup.py
# spark-3.3.4-bin-hadoop3/kubernetes/tests/decommissioning.py
# spark-3.3.4-bin-hadoop3/kubernetes/tests/autoscale.py
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/entrypoint.sh
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/decom.sh
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/Dockerfile.java17
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/Dockerfile
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/python/
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/python/Dockerfile
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/R/
# spark-3.3.4-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/R/Dockerfile
# spark-3.3.4-bin-hadoop3/yarn/
# spark-3.3.4-bin-hadoop3/yarn/spark-3.3.4-yarn-shuffle.jar
# spark-3.3.4-bin-hadoop3/jars/
# spark-3.3.4-bin-hadoop3/jars/zstd-jni-1.5.2-1.jar
# spark-3.3.4-bin-hadoop3/jars/zookeeper-jute-3.6.2.jar
# spark-3.3.4-bin-hadoop3/jars/zookeeper-3.6.2.jar
# spark-3.3.4-bin-hadoop3/jars/zjsonpatch-0.3.0.jar
# spark-3.3.4-bin-hadoop3/jars/xz-1.9.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-common-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-certificates-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-batch-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-autoscaling-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-apps-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-apiextensions-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-admissionregistration-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-client-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kryo-shaded-4.0.2.jar
# spark-3.3.4-bin-hadoop3/jars/jul-to-slf4j-1.7.32.jar
# spark-3.3.4-bin-hadoop3/jars/jta-1.1.jar
# spark-3.3.4-bin-hadoop3/jars/jsr305-3.0.0.jar
# spark-3.3.4-bin-hadoop3/jars/json4s-scalap_2.12-3.7.0-M11.jar
# spark-3.3.4-bin-hadoop3/jars/json4s-jackson_2.12-3.7.0-M11.jar
# spark-3.3.4-bin-hadoop3/jars/json4s-core_2.12-3.7.0-M11.jar
# spark-3.3.4-bin-hadoop3/jars/json4s-ast_2.12-3.7.0-M11.jar
# spark-3.3.4-bin-hadoop3/jars/json-1.8.jar
# spark-3.3.4-bin-hadoop3/jars/jpam-1.1.jar
# spark-3.3.4-bin-hadoop3/jars/jodd-core-3.5.2.jar
# spark-3.3.4-bin-hadoop3/jars/joda-time-2.10.13.jar
# spark-3.3.4-bin-hadoop3/jars/jline-2.14.6.jar
# spark-3.3.4-bin-hadoop3/jars/jersey-server-2.36.jar
# spark-3.3.4-bin-hadoop3/jars/jersey-hk2-2.36.jar
# spark-3.3.4-bin-hadoop3/jars/jersey-container-servlet-core-2.36.jar
# spark-3.3.4-bin-hadoop3/jars/jersey-container-servlet-2.36.jar
# spark-3.3.4-bin-hadoop3/jars/jersey-common-2.36.jar
# spark-3.3.4-bin-hadoop3/jars/jersey-client-2.36.jar
# spark-3.3.4-bin-hadoop3/jars/jdo-api-3.0.1.jar
# spark-3.3.4-bin-hadoop3/jars/jcl-over-slf4j-1.7.32.jar
# spark-3.3.4-bin-hadoop3/jars/jaxb-runtime-2.3.2.jar
# spark-3.3.4-bin-hadoop3/jars/javolution-5.5.1.jar
# spark-3.3.4-bin-hadoop3/jars/javax.jdo-3.2.0-m3.jar
# spark-3.3.4-bin-hadoop3/jars/javassist-3.25.0-GA.jar
# spark-3.3.4-bin-hadoop3/jars/janino-3.0.16.jar
# spark-3.3.4-bin-hadoop3/jars/jakarta.xml.bind-api-2.3.2.jar
# spark-3.3.4-bin-hadoop3/jars/jakarta.ws.rs-api-2.1.6.jar
# spark-3.3.4-bin-hadoop3/jars/jakarta.validation-api-2.0.2.jar
# spark-3.3.4-bin-hadoop3/jars/jakarta.servlet-api-4.0.3.jar
# spark-3.3.4-bin-hadoop3/jars/jakarta.inject-2.6.1.jar
# spark-3.3.4-bin-hadoop3/jars/jakarta.annotation-api-1.3.5.jar
# spark-3.3.4-bin-hadoop3/jars/jackson-module-scala_2.12-2.13.4.jar
# spark-3.3.4-bin-hadoop3/jars/jackson-mapper-asl-1.9.13.jar
# spark-3.3.4-bin-hadoop3/jars/jackson-datatype-jsr310-2.13.4.jar
# spark-3.3.4-bin-hadoop3/jars/jackson-dataformat-yaml-2.13.4.jar
# spark-3.3.4-bin-hadoop3/jars/jackson-databind-2.13.4.2.jar
# spark-3.3.4-bin-hadoop3/jars/jackson-core-asl-1.9.13.jar
# spark-3.3.4-bin-hadoop3/jars/jackson-core-2.13.4.jar
# spark-3.3.4-bin-hadoop3/jars/jackson-annotations-2.13.4.jar
# spark-3.3.4-bin-hadoop3/jars/ivy-2.5.1.jar
# spark-3.3.4-bin-hadoop3/jars/istack-commons-runtime-3.0.8.jar
# spark-3.3.4-bin-hadoop3/jars/httpcore-4.4.14.jar
# spark-3.3.4-bin-hadoop3/jars/httpclient-4.5.13.jar
# spark-3.3.4-bin-hadoop3/jars/hk2-utils-2.6.1.jar
# spark-3.3.4-bin-hadoop3/jars/hk2-locator-2.6.1.jar
# spark-3.3.4-bin-hadoop3/jars/hk2-api-2.6.1.jar
# spark-3.3.4-bin-hadoop3/jars/hive-vector-code-gen-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-storage-api-2.7.2.jar
# spark-3.3.4-bin-hadoop3/jars/hive-shims-scheduler-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-shims-common-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-shims-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-shims-0.23-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-service-rpc-3.1.2.jar
# spark-3.3.4-bin-hadoop3/jars/hive-serde-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-metastore-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-llap-common-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-jdbc-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-exec-2.3.9-core.jar
# spark-3.3.4-bin-hadoop3/jars/hive-common-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-cli-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hive-beeline-2.3.9.jar
# spark-3.3.4-bin-hadoop3/jars/hadoop-yarn-server-web-proxy-3.3.2.jar
# spark-3.3.4-bin-hadoop3/jars/hadoop-shaded-guava-1.1.1.jar
# spark-3.3.4-bin-hadoop3/jars/hadoop-client-runtime-3.3.2.jar
# spark-3.3.4-bin-hadoop3/jars/hadoop-client-api-3.3.2.jar
# spark-3.3.4-bin-hadoop3/jars/guava-14.0.1.jar
# spark-3.3.4-bin-hadoop3/jars/gson-2.2.4.jar
# spark-3.3.4-bin-hadoop3/jars/generex-1.0.2.jar
# spark-3.3.4-bin-hadoop3/jars/flatbuffers-java-1.12.0.jar
# spark-3.3.4-bin-hadoop3/jars/dropwizard-metrics-hadoop-metrics2-reporter-0.1.2.jar
# spark-3.3.4-bin-hadoop3/jars/derby-10.14.2.0.jar
# spark-3.3.4-bin-hadoop3/jars/datanucleus-rdbms-4.1.19.jar
# spark-3.3.4-bin-hadoop3/jars/datanucleus-core-4.1.17.jar
# spark-3.3.4-bin-hadoop3/jars/datanucleus-api-jdo-4.2.4.jar
# spark-3.3.4-bin-hadoop3/jars/curator-recipes-2.13.0.jar
# spark-3.3.4-bin-hadoop3/jars/curator-framework-2.13.0.jar
# spark-3.3.4-bin-hadoop3/jars/curator-client-2.13.0.jar
# spark-3.3.4-bin-hadoop3/jars/core-1.1.2.jar
# spark-3.3.4-bin-hadoop3/jars/compress-lzf-1.1.jar
# spark-3.3.4-bin-hadoop3/jars/commons-text-1.10.0.jar
# spark-3.3.4-bin-hadoop3/jars/commons-pool-1.5.4.jar
# spark-3.3.4-bin-hadoop3/jars/commons-math3-3.6.1.jar
# spark-3.3.4-bin-hadoop3/jars/commons-logging-1.1.3.jar
# spark-3.3.4-bin-hadoop3/jars/commons-lang3-3.12.0.jar
# spark-3.3.4-bin-hadoop3/jars/commons-lang-2.6.jar
# spark-3.3.4-bin-hadoop3/jars/commons-io-2.11.0.jar
# spark-3.3.4-bin-hadoop3/jars/commons-dbcp-1.4.jar
# spark-3.3.4-bin-hadoop3/jars/commons-crypto-1.1.0.jar
# spark-3.3.4-bin-hadoop3/jars/commons-compress-1.21.jar
# spark-3.3.4-bin-hadoop3/jars/commons-compiler-3.0.16.jar
# spark-3.3.4-bin-hadoop3/jars/commons-collections4-4.4.jar
# spark-3.3.4-bin-hadoop3/jars/commons-collections-3.2.2.jar
# spark-3.3.4-bin-hadoop3/jars/commons-codec-1.15.jar
# spark-3.3.4-bin-hadoop3/jars/commons-cli-1.5.0.jar
# spark-3.3.4-bin-hadoop3/jars/chill_2.12-0.10.0.jar
# spark-3.3.4-bin-hadoop3/jars/chill-java-0.10.0.jar
# spark-3.3.4-bin-hadoop3/jars/cats-kernel_2.12-2.1.1.jar
# spark-3.3.4-bin-hadoop3/jars/breeze_2.12-1.2.jar
# spark-3.3.4-bin-hadoop3/jars/breeze-macros_2.12-1.2.jar
# spark-3.3.4-bin-hadoop3/jars/bonecp-0.8.0.RELEASE.jar
# spark-3.3.4-bin-hadoop3/jars/blas-2.2.1.jar
# spark-3.3.4-bin-hadoop3/jars/avro-mapred-1.11.0.jar
# spark-3.3.4-bin-hadoop3/jars/avro-ipc-1.11.0.jar
# spark-3.3.4-bin-hadoop3/jars/avro-1.11.0.jar
# spark-3.3.4-bin-hadoop3/jars/automaton-1.11-8.jar
# spark-3.3.4-bin-hadoop3/jars/audience-annotations-0.5.0.jar
# spark-3.3.4-bin-hadoop3/jars/arrow-vector-7.0.0.jar
# spark-3.3.4-bin-hadoop3/jars/arrow-memory-netty-7.0.0.jar
# spark-3.3.4-bin-hadoop3/jars/arrow-memory-core-7.0.0.jar
# spark-3.3.4-bin-hadoop3/jars/arrow-format-7.0.0.jar
# spark-3.3.4-bin-hadoop3/jars/arpack_combined_all-0.1.jar
# spark-3.3.4-bin-hadoop3/jars/arpack-2.2.1.jar
# spark-3.3.4-bin-hadoop3/jars/aopalliance-repackaged-2.6.1.jar
# spark-3.3.4-bin-hadoop3/jars/antlr4-runtime-4.8.jar
# spark-3.3.4-bin-hadoop3/jars/antlr-runtime-3.5.2.jar
# spark-3.3.4-bin-hadoop3/jars/annotations-17.0.0.jar
# spark-3.3.4-bin-hadoop3/jars/algebra_2.12-2.0.1.jar
# spark-3.3.4-bin-hadoop3/jars/aircompressor-0.21.jar
# spark-3.3.4-bin-hadoop3/jars/activation-1.1.1.jar
# spark-3.3.4-bin-hadoop3/jars/ST4-4.0.4.jar
# spark-3.3.4-bin-hadoop3/jars/RoaringBitmap-0.9.25.jar
# spark-3.3.4-bin-hadoop3/jars/JTransforms-3.1.jar
# spark-3.3.4-bin-hadoop3/jars/JLargeArrays-1.5.jar
# spark-3.3.4-bin-hadoop3/jars/HikariCP-2.5.1.jar
# spark-3.3.4-bin-hadoop3/jars/xbean-asm9-shaded-4.20.jar
# spark-3.3.4-bin-hadoop3/jars/velocity-1.5.jar
# spark-3.3.4-bin-hadoop3/jars/univocity-parsers-2.9.1.jar
# spark-3.3.4-bin-hadoop3/jars/transaction-api-1.1.jar
# spark-3.3.4-bin-hadoop3/jars/tink-1.6.1.jar
# spark-3.3.4-bin-hadoop3/jars/threeten-extra-1.5.0.jar
# spark-3.3.4-bin-hadoop3/jars/super-csv-2.2.0.jar
# spark-3.3.4-bin-hadoop3/jars/stream-2.9.6.jar
# spark-3.3.4-bin-hadoop3/jars/stax-api-1.0.1.jar
# spark-3.3.4-bin-hadoop3/jars/spire_2.12-0.17.0.jar
# spark-3.3.4-bin-hadoop3/jars/spire-util_2.12-0.17.0.jar
# spark-3.3.4-bin-hadoop3/jars/spire-platform_2.12-0.17.0.jar
# spark-3.3.4-bin-hadoop3/jars/spire-macros_2.12-0.17.0.jar
# spark-3.3.4-bin-hadoop3/jars/spark-yarn_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-unsafe_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-tags_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-tags_2.12-3.3.4-tests.jar
# spark-3.3.4-bin-hadoop3/jars/spark-streaming_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-sql_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-sketch_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-repl_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-network-shuffle_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-network-common_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-mllib_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-mllib-local_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-mesos_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-launcher_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-kvstore_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-kubernetes_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-hive_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-hive-thriftserver_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-graphx_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-core_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/spark-catalyst_2.12-3.3.4.jar
# spark-3.3.4-bin-hadoop3/jars/snappy-java-1.1.8.4.jar
# spark-3.3.4-bin-hadoop3/jars/snakeyaml-1.31.jar
# spark-3.3.4-bin-hadoop3/jars/slf4j-api-1.7.32.jar
# spark-3.3.4-bin-hadoop3/jars/shims-0.9.25.jar
# spark-3.3.4-bin-hadoop3/jars/shapeless_2.12-2.3.7.jar
# spark-3.3.4-bin-hadoop3/jars/scala-xml_2.12-1.2.0.jar
# spark-3.3.4-bin-hadoop3/jars/scala-reflect-2.12.15.jar
# spark-3.3.4-bin-hadoop3/jars/scala-parser-combinators_2.12-1.1.2.jar
# spark-3.3.4-bin-hadoop3/jars/scala-library-2.12.15.jar
# spark-3.3.4-bin-hadoop3/jars/scala-compiler-2.12.15.jar
# spark-3.3.4-bin-hadoop3/jars/scala-collection-compat_2.12-2.1.1.jar
# spark-3.3.4-bin-hadoop3/jars/rocksdbjni-6.20.3.jar
# spark-3.3.4-bin-hadoop3/jars/py4j-0.10.9.5.jar
# spark-3.3.4-bin-hadoop3/jars/protobuf-java-2.5.0.jar
# spark-3.3.4-bin-hadoop3/jars/pickle-1.2.jar
# spark-3.3.4-bin-hadoop3/jars/parquet-jackson-1.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/parquet-hadoop-1.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/parquet-format-structures-1.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/parquet-encoding-1.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/parquet-common-1.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/parquet-column-1.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/paranamer-2.8.jar
# spark-3.3.4-bin-hadoop3/jars/osgi-resource-locator-1.0.3.jar
# spark-3.3.4-bin-hadoop3/jars/oro-2.0.8.jar
# spark-3.3.4-bin-hadoop3/jars/orc-shims-1.7.10.jar
# spark-3.3.4-bin-hadoop3/jars/orc-mapreduce-1.7.10.jar
# spark-3.3.4-bin-hadoop3/jars/orc-core-1.7.10.jar
# spark-3.3.4-bin-hadoop3/jars/opencsv-2.3.jar
# spark-3.3.4-bin-hadoop3/jars/okio-1.14.0.jar
# spark-3.3.4-bin-hadoop3/jars/okhttp-3.12.12.jar
# spark-3.3.4-bin-hadoop3/jars/objenesis-3.2.jar
# spark-3.3.4-bin-hadoop3/jars/netty-transport-native-unix-common-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-transport-native-kqueue-4.1.74.Final-osx-x86_64.jar
# spark-3.3.4-bin-hadoop3/jars/netty-transport-native-kqueue-4.1.74.Final-osx-aarch_64.jar
# spark-3.3.4-bin-hadoop3/jars/netty-transport-native-epoll-4.1.74.Final-linux-x86_64.jar
# spark-3.3.4-bin-hadoop3/jars/netty-transport-native-epoll-4.1.74.Final-linux-aarch_64.jar
# spark-3.3.4-bin-hadoop3/jars/netty-transport-classes-kqueue-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-transport-classes-epoll-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-transport-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-tcnative-classes-2.0.48.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-resolver-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-handler-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-common-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-codec-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-buffer-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/netty-all-4.1.74.Final.jar
# spark-3.3.4-bin-hadoop3/jars/minlog-1.3.0.jar
# spark-3.3.4-bin-hadoop3/jars/metrics-jvm-4.2.7.jar
# spark-3.3.4-bin-hadoop3/jars/metrics-json-4.2.7.jar
# spark-3.3.4-bin-hadoop3/jars/metrics-jmx-4.2.7.jar
# spark-3.3.4-bin-hadoop3/jars/metrics-graphite-4.2.7.jar
# spark-3.3.4-bin-hadoop3/jars/metrics-core-4.2.7.jar
# spark-3.3.4-bin-hadoop3/jars/mesos-1.4.3-shaded-protobuf.jar
# spark-3.3.4-bin-hadoop3/jars/lz4-java-1.8.0.jar
# spark-3.3.4-bin-hadoop3/jars/logging-interceptor-3.12.12.jar
# spark-3.3.4-bin-hadoop3/jars/log4j-slf4j-impl-2.17.2.jar
# spark-3.3.4-bin-hadoop3/jars/log4j-core-2.17.2.jar
# spark-3.3.4-bin-hadoop3/jars/log4j-api-2.17.2.jar
# spark-3.3.4-bin-hadoop3/jars/log4j-1.2-api-2.17.2.jar
# spark-3.3.4-bin-hadoop3/jars/libthrift-0.12.0.jar
# spark-3.3.4-bin-hadoop3/jars/libfb303-0.9.3.jar
# spark-3.3.4-bin-hadoop3/jars/leveldbjni-all-1.8.jar
# spark-3.3.4-bin-hadoop3/jars/lapack-2.2.1.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-storageclass-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-scheduling-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-rbac-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-policy-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-node-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-networking-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-metrics-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-flowcontrol-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-extensions-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-events-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-discovery-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-core-5.12.2.jar
# spark-3.3.4-bin-hadoop3/jars/kubernetes-model-coordination-5.12.2.jar
# spark-3.3.4-bin-hadoop3/RELEASE

# %%
'''
Setting the environment path that enables PySpark to run in this Colab environment.
'''

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.3.4-bin-hadoop3"

# %%
'''
Running a local spark session to test the installation.
'''

import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
'''
Import libraries
'''

import pyspark.pandas as ps
from pyspark.sql import Window
from pyspark.sql.functions import udf,col,window, max as Fmax
from pyspark.sql.functions import *
from pyspark.sql.types import IntegerType,TimestampType
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.ml.classification import LogisticRegression,RandomForestClassifier,DecisionTreeClassifier
import numpy as np
from pyspark.ml.feature import VectorAssembler, StandardScaler, StringIndexer
from pyspark.ml import Pipeline
from pyspark.sql import functions as f
import time
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder,CrossValidator
from builtins import round
# Out:
# /content/spark-3.3.4-bin-hadoop3/python/pyspark/pandas/__init__.py:49: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(

# %%
# Creating a Spark session

spark = SparkSession \
    .builder \
    .appName("Churn Prediction") \
    .config("spark.ui.port", "4050") \
    .getOrCreate()

# %% [markdown]
# TEXT PREPROCESSING

# %% [markdown]
# # **1. Load Data into Spark**

# %%
from pyspark import SparkFiles
from pyspark.sql import SparkSession
#spark.sparkContext.addFile("https://udacity-dsnd.s3.amazonaws.com/sparkify/mini_sparkify_event_data.json")
spark.sparkContext.addFile("https://udacity-dsnd.s3.amazonaws.com/sparkify/sparkify_event_data.json")

#s3n://udacity-dsnd/sparkify/sparkify_event_data.json
#https://udacity-dsnd.s3.amazonaws.com/sparkify/sparkify_event_data.json
data = spark.read.json("file://" +SparkFiles.get("sparkify_event_data.json"))

# %%
data.show(30)
# Out:
# +--------------------+----------+---------+------+-------------+---------+----------+-----+--------------------+------+---------+-------------+---------+--------------------+------+-------------+--------------------+-------+
# |              artist|      auth|firstName|gender|itemInSession| lastName|    length|level|            location|method|     page| registration|sessionId|                song|status|           ts|           userAgent| userId|
# +--------------------+----------+---------+------+-------------+---------+----------+-----+--------------------+------+---------+-------------+---------+--------------------+------+-------------+--------------------+-------+
# |           Popol Vuh| Logged In|    Shlok|     M|          278|  Johnson| 524.32934| paid|Dallas-Fort Worth...|   PUT| NextSong|1533734541000|    22683|Ich mache einen S...|   200|1538352001000|"Mozilla/5.0 (Win...|1749042|
# |         Los Bunkers| Logged In|  Vianney|     F|            9|   Miller| 238.39302| paid|San Francisco-Oak...|   PUT| NextSong|1537500318000|    20836|         MiÃÂ©ntele|   200|1538352002000|"Mozilla/5.0 (Mac...|1563081|
# |                Lush| Logged In|     Vina|     F|          109|   Bailey| 140.35546| paid|            Hilo, HI|   PUT| NextSong|1536414505000|     4593|           Baby Talk|   200|1538352002000|Mozilla/5.0 (Maci...|1697168|
# |Barry Tuckwell/Ac...| Logged In|   Andres|     M|           71|    Foley| 277.15873| paid|       Watertown, SD|   PUT| NextSong|1534386660000|     6370|Horn Concerto No....|   200|1538352003000|"Mozilla/5.0 (Mac...|1222580|
# |                 Yes| Logged In|  Aaliyah|     F|           21|  Ramirez|1121.25342| paid|Baltimore-Columbi...|   PUT| NextSong|1537381415000|    22316|Close To The Edge...|   200|1538352003000|"Mozilla/5.0 (Win...|1714398|
# |                MGMT| Logged In|     Ryan|     M|            8| Williams| 229.25016| paid|Cape Coral-Fort M...|   PUT| NextSong|1537602560000|    23924|       Electric Feel|   200|1538352004000|"Mozilla/5.0 (Win...|1010522|
# |   Animal Collective| Logged In|    Isaac|     M|            6|    Brown|  313.5473| free|          Kokomo, IN|   PUT| NextSong|1536563853000|     1746|              Bluish|   200|1538352005000|Mozilla/5.0 (Wind...|1475659|
# |              Eminem| Logged In| Jonathan|     M|           29|   Martin|  250.8273| free|New York-Newark-J...|   PUT| NextSong|1538069376000|    22483|         Mockingbird|   200|1538352006000|"Mozilla/5.0 (Win...|1465194|
# |         Leona Lewis| Logged In| Jennifer|     F|            0|  Shelton| 203.88526| free|      Pittsburgh, PA|   PUT| NextSong|1536455539000|    25128|          Forgive Me|   200|1538352006000|"Mozilla/5.0 (Win...|1558463|
# |     The Cranberries| Logged In|  Michael|     M|           13|    Riley| 183.87546| paid|Albany-Schenectad...|   PUT| NextSong|1533220062000|     3992|         The Concept|   200|1538352006000|"Mozilla/5.0 (Win...|1605667|
# |        Mariah Carey| Logged In|    Azari|     M|           37|   Hansen|  265.9522| free|    Martinsville, VA|   PUT| NextSong|1534393835000|    14642|Anytime You Need ...|   200|1538352006000|"Mozilla/5.0 (X11...|1385500|
# |Johnny Cash with ...| Logged In|    Riley|     F|          300|Hernandez| 199.81016| paid|         Reading, PA|   PUT| NextSong|1537618545000|    14853|   Nine Pound Hammer|   200|1538352006000|"Mozilla/5.0 (Mac...|1032628|
# |            Gorillaz| Logged In|    Brian|     M|           73|    Allen| 131.91791| free|San Diego-Carlsba...|   PUT| NextSong|1537868758000|     2526|Don't Get Lost In...|   200|1538352007000|"Mozilla/5.0 (Mac...|1901081|
# |     Los Prisioneros| Logged In|  Brayden|     M|           95|Armstrong| 248.78975| paid|Dallas-Fort Worth...|   PUT| NextSong|1534635513000|    23917|   La Voz De Los '80|   200|1538352007000|"Mozilla/5.0 (Win...|1611729|
# |   The White Stripes| Logged In|   Brooke|     F|            6|    Kirby| 126.40608| paid|Los Angeles-Long ...|   PUT| NextSong|1531817572000|    14085|          Good To Me|   200|1538352008000|"Mozilla/5.0 (Win...|1497881|
# |   Brigitte Fontaine| Logged In|  Caitlin|     F|          117|  Barnett| 355.57832| free|Philadelphia-Camd...|   PUT| NextSong|1528964849000|     2303|Ah Que La Vie Est...|   200|1538352008000|"Mozilla/5.0 (Mac...|1413952|
# |      Alien Ant Farm| Logged In|   Aminah|     F|            8|    Payne|  204.7473| free|Virginia Beach-No...|   PUT| NextSong|1536761240000|    19434|                Wish|   200|1538352008000|Mozilla/5.0 (X11;...|1585800|
# |                null|Logged Out|     null|  null|           87|     null|      null| paid|                null|   GET|     Home|         null|     8615|                null|   200|1538352008000|                null|1261737|
# |                null| Logged In|  Valarie|     F|          206|    Moore|      null| paid|Los Angeles-Long ...|   GET|     Home|1537790336000|     2948|                null|   200|1538352008000|"Mozilla/5.0 (Win...|1009070|
# |          Dan Mangan| Logged In|    Hanna|     F|           15|   Peters| 293.85098| free|Boston-Cambridge-...|   PUT| NextSong|1534217490000|     7804|Some Place To Com...|   200|1538352010000|"Mozilla/5.0 (Win...|1041334|
# |   Nortec Collective| Logged In|   Sophia|     F|            8|   Dalton| 267.12771| free|         El Paso, TX|   PUT| NextSong|1536693084000|      655|      Olvidela Compa|   200|1538352010000|"Mozilla/5.0 (Mac...|1526624|
# |    The Decemberists| Logged In|     Kane|     M|            3|    Hicks| 256.80934| free|      Crossville, TN|   PUT| NextSong|1534705560000|     8030|Los Angeles_ I'm ...|   200|1538352011000|"Mozilla/5.0 (X11...|1527155|
# |                Dido| Logged In|   Weston|     M|          100|    Allen| 235.57179| free|          Athens, TX|   PUT| NextSong|1536383474000|     7489|        I'm No Angel|   200|1538352011000|"Mozilla/5.0 (Win...|1144647|
# |                null| Logged In|   Sophia|     F|            9|   Dalton|      null| free|         El Paso, TX|   PUT|Thumbs Up|1536693084000|      655|                null|   307|1538352011000|"Mozilla/5.0 (Mac...|1526624|
# |Five Finger Death...| Logged In|    David|     M|          190|    Ortiz| 262.42567| paid|Atlanta-Sandy Spr...|   PUT| NextSong|1536984036000|    22596|         Bad Company|   200|1538352012000|"Mozilla/5.0 (Mac...|1834381|
# |Dykes' Magic City...| Logged In| Serenity|     F|           32|   Carter| 177.10975| free|Lexington-Fayette...|   PUT| NextSong|1537256649000|     6563|             Frankie|   200|1538352012000|"Mozilla/5.0 (Mac...|1447418|
# |       Brooks & Dunn| Logged In|Elizabeth|     F|          182|    Quinn| 169.97832| paid|    St. Louis, MO-IL|   PUT| NextSong|1530607056000|      506|She's About As Lo...|   200|1538352012000|Mozilla/5.0 (Wind...|1558459|
# |             BlÃÂ¸f| Logged In|Salvatore|     M|           33|  Huffman| 229.82485| free|Washington-Arling...|   PUT| NextSong|1537382061000|    10220|       Niets Dan Dit|   200|1538352013000|Mozilla/5.0 (X11;...|1240184|
# |                null| Logged In|  Anthony|     M|           12|     Diaz|      null| paid|New York-Newark-J...|   GET|    Error|1538045178000|    11807|                null|   404|1538352013000|"Mozilla/5.0 (Mac...|1507202|
# |            BjÃÂ¶rk| Logged In|  Zachary|     M|           19|Rodriguez| 348.57751| free|Washington-Arling...|   PUT| NextSong|1537691785000|     3050|                Undo|   200|1538352013000|Mozilla/5.0 (Wind...|1527982|
# +--------------------+----------+---------+------+-------------+---------+----------+-----+--------------------+------+---------+-------------+---------+--------------------+------+-------------+--------------------+-------+
# only showing top 30 rows

# %% [markdown]
# # **Explore and Clean Data**

# %%
#data1.where(data1['_corrupt_record'].isNotNull()).show()

# %%
# Structure of the dataframe
data.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
#Column types
data.dtypes
# Out:
# [('artist', 'string'),
#  ('auth', 'string'),
#  ('firstName', 'string'),
#  ('gender', 'string'),
#  ('itemInSession', 'bigint'),
#  ('lastName', 'string'),
#  ('length', 'double'),
#  ('level', 'string'),
#  ('location', 'string'),
#  ('method', 'string'),
#  ('page', 'string'),
#  ('registration', 'bigint'),
#  ('sessionId', 'bigint'),
#  ('song', 'string'),
#  ('status', 'bigint'),
#  ('ts', 'bigint'),
#  ('userAgent', 'string'),
#  ('userId', 'string')]

# %%
data.count()
# Out:
# 26259199

# %%
#Number of users
data.select('userId').distinct().count()
# Out:
# 22278

# %%
'''
 Rows with empty string in the 'userId' column correspond to logs in which user has not been logged in
 that is 'Logged Out' or 'Guest' authentication levels.
 '''

data.where(data['userId']=='').groupby('auth').count().show()
# Out:
# +----+-----+
# |auth|count|
# +----+-----+
# +----+-----+

# %%
data.groupby('auth').count().show()
#data1.groupby('auth').count()
# Out:
# +----------+--------+
# |      auth|   count|
# +----------+--------+
# |Logged Out|  774285|
# | Cancelled|    5003|
# |     Guest|    4194|
# | Logged In|25475717|
# +----------+--------+

# %%
data.groupby('page').count().show()
# Out:
# +--------------------+--------+
# |                page|   count|
# +--------------------+--------+
# |              Cancel|    5003|
# |    Submit Downgrade|    6494|
# |         Thumbs Down|  239212|
# |                Home| 1343102|
# |           Downgrade|  184240|
# |         Roll Advert|  385212|
# |              Logout|  296005|
# |       Save Settings|   29516|
# |Cancellation Conf...|    5003|
# |               About|   92759|
# | Submit Registration|     401|
# |            Settings|  147074|
# |               Login|  296350|
# |            Register|     802|
# |     Add to Playlist|  597921|
# |          Add Friend|  381664|
# |            NextSong|20850272|
# |           Thumbs Up| 1151465|
# |                Help|  155100|
# |             Upgrade|   50507|
# +--------------------+--------+
# only showing top 20 rows

# %%
data=data.pandas_api()

# %%
#How many users dropped off and what was the level of their account(free or paid)?

data[data.page=='Cancellation Confirmation'].groupby(['level','page']).count()['userId']
# Out:
# level  page
# free   Cancellation Confirmation    1579
# paid   Cancellation Confirmation    3424
# Name: userId, dtype: int64

# %%
## Number of users that tried downgrading from paid to free and number of users that actually downgraded from paid to free

#Downgraded_users.userId.nunique()
#data[data.page=='Downgrade']['userId'].nunique()
print('{} users tried downgrading from paid to free and {} actually downgraded from paid to free.'.format(data[data.page=='Downgrade']['userId'].nunique(),data[data.page=='Submit Downgrade']['userId'].nunique()))
# Out:
# 15209 users tried downgrading from paid to free and 5103 actually downgraded from paid to free.

# %%
data=data.to_spark()
# Out:
# /content/spark-3.3.4-bin-hadoop3/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `to_spark`, the existing index is lost when converting to Spark DataFrame.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %% [markdown]
# # **Create Features**

# %%
data = data.withColumn('date', timestamp_seconds(data.ts/1000))
#data1 = data1.withColumn('tsDate', (data1['ts'] / 1000).cast(TimestampType()))

# %% [markdown]
# ## Define Churn
#
# `Cancellation Confirmation` and `Submit Downgrade` events make up our definition for churn. `Cancellation Confirmation` happens for both paid and free users who cancel the services. `Submit Downgrade` happens for premium users who downgrades to free tier.

# %%
# Add the column 'churn' to identify users that churned. 1 for yes, 0 for no
df = data.withColumn('churn', when(data.page == 'Cancellation Confirmation',1).when(data.page == 'Submit Downgrade', 1).otherwise(0))
df = df.withColumn('user_churn', Fmax('churn').over(Window.partitionBy('UserId')))

# %% [markdown]
# ####Time between registration and drop-off(churn)

# %%
#First 2 lines creates a dataframe with a new column for the difference in when user registered and the timestamp of that activity

life_time_df = df.groupby(['user_churn', 'userId', 'ts', 'registration']).count() \
                    .withColumn('life_time', (df.ts - df.registration) / 1000) \
                    .groupBy('userId', 'user_churn').agg({'life_time' : 'max'}).withColumnRenamed('max(life_time)','life_span')
#df.where(df.userId==105).tail(10)
life_time_df.show()
#life_time_df.where(life_time_df.user_churn==1).show()
# Out:
# +-------+----------+-----------+
# | userId|user_churn|  life_span|
# +-------+----------+-----------+
# |1000280|         1|  6679046.0|
# |1000353|         1| 1.498609E7|
# |1000503|         1|  9039679.0|
# |1001129|         1|  7771324.0|
# |1001163|         1|  5253389.0|
# |1001246|         1|  7317326.0|
# |1001393|         0|  5173895.0|
# |1001450|         0|  6584243.0|
# |1001559|         0|  5507913.0|
# |1001607|         1|  5817002.0|
# |1001759|         0|  1884881.0|
# |1001904|         0|  6092129.0|
# |1001963|         0|  3721823.0|
# |1002143|         0|  6874233.0|
# |1002185|         0|  5680891.0|
# |1002295|         0|1.2505832E7|
# |1002397|         1|1.0227863E7|
# |1002409|         0|  4940810.0|
# |1002491|         0|  7667619.0|
# |1002493|         1|   918698.0|
# +-------+----------+-----------+
# only showing top 20 rows

# %% [markdown]
# ###Gender

# %%
features = ps.DataFrame(dtype='int64')

gender = data.groupby('userId').agg(first(when(data['gender']=='M',0).otherwise(1))).withColumnRenamed('first(CASE WHEN (gender = M) THEN 0 ELSE 1 END)', 'gender')
features = gender
features.show()
# Out:
# /content/spark-3.3.4-bin-hadoop3/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /content/spark-3.3.4-bin-hadoop3/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# +-------+------+
# | userId|gender|
# +-------+------+
# |1390009|     0|
# |1519090|     1|
# |1394508|     0|
# |1178731|     1|
# |1351489|     0|
# |1358765|     0|
# |1500901|     0|
# |1718034|     0|
# |1384823|     1|
# |1083324|     0|
# |1633577|     1|
# |1875484|     0|
# |1492713|     0|
# |1658815|     1|
# |1114507|     1|
# |1331962|     0|
# |1588738|     1|
# |1338783|     1|
# |1965481|     0|
# |1057724|     0|
# +-------+------+
# only showing top 20 rows

# %% [markdown]
# ###Number of songs each user listened to

# %%
no_of_songsdf = data.where(data['page']== 'NextSong').groupby('userId').count()\
                .withColumnRenamed('count', 'songs')

features = features.join(no_of_songsdf, on = 'userId', how='left').withColumn('songs',when(col('songs').isNull(), 0).otherwise(col('songs')))

# %%
features = features.join(life_time_df, on = 'userId')

# %% [markdown]
# ###Number of thumbs up and thumbs down given

# %%
#Thumbs_Down = data1.withColumn('Thumbs Down',when(data1.page == 'Thumbs Down', 1).otherwise(0))
Thumbs_Down = data.groupBy('userId').agg(sum(when(data.page == 'Thumbs Down', 1).otherwise(0))).withColumnRenamed('sum(CASE WHEN (page = Thumbs Down) THEN 1 ELSE 0 END)','Thumbs Down')


#data1.filter(data1.page=='Thumbs Down').show()
Thumbs_Up = data.groupBy('userId').agg(sum(when(data.page == 'Thumbs Up', 1).otherwise(0))).withColumnRenamed('sum(CASE WHEN (page = Thumbs Up) THEN 1 ELSE 0 END)','Thumbs Up')


features = features.join(Thumbs_Down, on = 'userId')
features = features.join(Thumbs_Up, on = 'userId')

features.show()
# Out:
# +-------+------+-----+----------+-----------+-----------+---------+
# | userId|gender|songs|user_churn|  life_span|Thumbs Down|Thumbs Up|
# +-------+------+-----+----------+-----------+-----------+---------+
# |1000280|     0| 1022|         1|  6679046.0|         33|       53|
# |1000353|     1|  239|         1| 1.498609E7|          4|       13|
# |1000503|     1|  191|         1|  9039679.0|          3|        3|
# |1001129|     0|  557|         1|  7771324.0|         10|       25|
# |1001163|     1|  258|         1|  5253389.0|          2|        8|
# |1001246|     1|  687|         1|  7317326.0|          8|       59|
# |1001393|     0|  494|         0|  5173895.0|          6|       43|
# |1001450|     0|   31|         0|  6584243.0|          2|        1|
# |1001559|     1| 1016|         0|  5507913.0|          6|       51|
# |1001607|     1| 1929|         1|  5817002.0|         16|      107|
# |1001759|     0|   57|         0|  1884881.0|          1|        4|
# |1001904|     1| 1380|         0|  6092129.0|         18|       74|
# |1001963|     1|  607|         0|  3721823.0|         12|       30|
# |1002143|     0|  359|         0|  6874233.0|          5|       24|
# |1002185|     1| 1778|         0|  5680891.0|         14|       92|
# |1002295|     0|  872|         0|1.2505832E7|          7|       42|
# |1002397|     0|  176|         1|1.0227863E7|          0|        6|
# |1002409|     1|  179|         0|  4940810.0|          2|        9|
# |1002491|     0|  887|         0|  7667619.0|          8|       43|
# |1002493|     0|  520|         1|   918698.0|          8|       16|
# +-------+------+-----+----------+-----------+-----------+---------+
# only showing top 20 rows

# %% [markdown]
# ####Level of User (free/paid)

# %%
users_level = data.groupBy('userId').agg(first(when(data['level']=='free',0).otherwise(1)))\
.withColumnRenamed('first(CASE WHEN (level = free) THEN 0 ELSE 1 END)', 'level')\
.na.drop() #or .dropna()
features = features.join(users_level, on = 'userId')

# %% [markdown]
# ###Location of user

# %%
#Split the location column into two new columns - City and State
data = data.withColumn('City',pyspark.sql.functions.split(data['location'], ',').getItem(0)).withColumn('State',pyspark.sql.functions.split(data['location'], ',').getItem(1))
indexer = StringIndexer(inputCol="State", outputCol="StateIndex", handleInvalid="skip")
data = indexer.fit(data).transform(data)
users_location = data.groupBy('userId').agg(last('StateIndex').alias('StateIndex')).na.drop() #or .dropna()
features = features.join(users_location, on = 'userId')

# %%
data=data.drop('State')
#data.isnull('StateIndex')

# %%
#Users that churned, whats the proportion of free to paid users
#data1.filter(data1['page']=='Help').groupBy('level').count().show()
Visted_help_pg = data.filter(data.page=='Help')
#Help_count = Visted_help_pg.groupby('userId').agg(countDistinct('page').alias('Helps_count')).when(data1.Helps_count == null, 0).otherwise(data1.Helps_count)
Help_count = Visted_help_pg.groupby('userId').agg(countDistinct('page').alias('Help_count'))
features = features.join(Help_count, on = 'userId').withColumn('Help_count',(when(col(('Help_count')).isNull(), 0).otherwise(col(('Help_count')))))

# %% [markdown]
# ####Users' number of downgrade and upgrades

# %%
Downgrade_No = data.groupBy('userId').agg(sum(when(data.page=='Submit Downgrade',1).otherwise(0)).alias('Downgrades'))
Upgrade_No = data.groupBy('userId').agg(sum(when(data.page=='Submit Upgrade',1).otherwise(0)).alias('Upgrades'))
features = features.join(Downgrade_No, on = 'userId')
features = features.join(Upgrade_No, on = 'userId')

# %% [markdown]
# Number of songs in users'playlist

# %%
Playlist_No = data.groupBy('userId').agg(sum(when(data.page=='Add to Playlist',1).otherwise(0)).alias('Playlist_no'))
features = features.join(Playlist_No, on = 'userId')

# %% [markdown]
# Number of friends

# %%
Friend_No = data.groupBy('userId').agg(sum(when(data.page=='Add Friend',1).otherwise(0)).alias('Friend_no'))
features = features.join(Friend_No, on = 'userId')

# %% [markdown]
#  In a distributed environment it can be a little more complicated to take raw DataFrames as an input for training so we would be using Assemblers to prepare our training data. VectorAssember from Spark ML library is a module that allows to convert numerical features into a single vector that is used by the machine learning models.

# %%
assembler = VectorAssembler(
    inputCols=['songs','Thumbs Down','Thumbs Up','Help_count','Downgrades','Upgrades','life_span','Playlist_no','Friend_no'],
    outputCol="features",handleInvalid = "keep" )
output_vector = assembler.transform(features)

scaler = StandardScaler(inputCol='features', outputCol ='num_vector_sc', withStd=True, withMean=True)
output_scaler = scaler.fit(output_vector).transform(output_vector)

final_assembler = VectorAssembler(inputCols=['num_vector_sc'] + ['gender','level'],outputCol='new_features')
final_vector = final_assembler.transform(output_scaler)

# %%
#final data
final_data = final_vector.select(final_vector.user_churn, final_vector.new_features)

# %% [markdown]
# ## **Build models**

# %%
##Splitting final data into train and test dataset

train, test = final_data.randomSplit([0.8, 0.2], 42)

# %%
# function for printing metric results
def evaluate_result(model_result, model_name, start, end):

    evaluator = MulticlassClassificationEvaluator(predictionCol='prediction')
    evaluator.setLabelCol('user_churn')
    accuracy = evaluator.evaluate(model_result, {evaluator.metricName : 'accuracy'})
    f1 = evaluator.evaluate(model_result, {evaluator.metricName : 'f1'})
    weightedPrecision = evaluator.evaluate(model_result, {evaluator.metricName : 'weightedPrecision'})
    weightedRecall = evaluator.evaluate(model_result, {evaluator.metricName : 'weightedRecall'})
    time = (end - start)/60
    result = [model_name, round(accuracy,3), round(f1,3), round(time,1)]

    print('{} performance metrics:'.format(model_name))
    print('Accuracy: {:.0%}'.format(accuracy))
    print('F-1 Score: {}'.format(f1))
    print('weightedPrecision: {}'.format(weightedPrecision))
    print('weightedRecall: {}'.format(weightedRecall))
    print('Total training time: {} minutes'.format(time))

    return result

# %%
# start training
START = time.time()

# %% [markdown]
# ##Logistics Regression

# %%
log_reg = LogisticRegression(maxIter=10, labelCol='user_churn', featuresCol='new_features')
evaluator = MulticlassClassificationEvaluator(labelCol='user_churn')

pipeline = Pipeline(stages=[log_reg])
log_reg_paramGrid = (ParamGridBuilder()
                .addGrid(log_reg.regParam, [0.1, 0.01, 0.001])
                .addGrid(log_reg.elasticNetParam, [0.1, 0.01, 0.5])
                .build())


crossval = CrossValidator(
    estimator=pipeline,
    estimatorParamMaps=log_reg_paramGrid,
    evaluator=evaluator,
    numFolds=3)

log_reg_start = time.time()
log_reg_model = crossval.fit(train)
log_reg_end = time.time()

# %%
log_reg_results = log_reg_model.transform(test)

log_reg_safe = evaluate_result(log_reg_results, 'Logistic Regression', log_reg_start, log_reg_end)

best_param = list(log_reg_model.getEstimatorParamMaps()[np.argmax(log_reg_model.avgMetrics)].values())
print('Best regression parameter(regParam) is {}, Best elasticNet parameter(elasticNetParam) is {}'.format(best_param[0],best_param[1]))
# Out:
# Logistic Regression performance metrics:
# Accuracy: 91%
# F-1 Score: 0.909148565086412
# weightedPrecision: 0.9234693877551021
# weightedRecall: 0.9142857142857144
# Total training time: 20.175902156035104 minutes
# Best regression parameter(regParam) is 0.001, Best elasticNet parameter(elasticNetParam) is 0.01

# %%
lr_results.show()

# %% [markdown]
# ## Random Forest

# %%
ran_forest = RandomForestClassifier(numTrees=3, maxDepth=2, labelCol='user_churn', featuresCol='new_features',seed=42,leafCol="leafId")
evaluator = MulticlassClassificationEvaluator(labelCol='user_churn')

pipeline = Pipeline(stages=[ran_forest])
ran_forest_paramGrid = (ParamGridBuilder()
                .addGrid(ran_forest.numTrees, [2, 3, 4])
                .addGrid(ran_forest.maxDepth, [2, 3, 4,5])
                .build())


crossval = CrossValidator(
    estimator=pipeline,
    estimatorParamMaps=ran_forest_paramGrid,
    evaluator=evaluator,
    numFolds=3)

ran_forest_start = time.time()
ran_forest_model = crossval.fit(train)
ran_forest_end = time.time()

# %%
ran_forest_results = ran_forest_model.transform(test)
ran_forest_safe = evaluate_result(ran_forest_results, 'Random Forest', ran_forest_start, ran_forest_end)

best_param = list(ran_forest_model.getEstimatorParamMaps()[np.argmax(ran_forest_model.avgMetrics)].values())
print('Best numTrees parameter is {}, Best maxDepth parameter is {}.'.format(best_param[0],best_param[1]))
# Out:
# Random Forest performance metrics:
# Accuracy: 91%
# F-1 Score: 0.9128704113224237
# weightedPrecision: 0.9133089133089133
# weightedRecall: 0.9142857142857143
# Total training time: 16.961500136057534 minutes
# Best numTrees parameter is 3, Best maxDepth parameter is 5.

# %% [markdown]
# ## Decision Tree

# %%
dec_tree = DecisionTreeClassifier(maxDepth=2,maxBins=32, labelCol='user_churn', featuresCol='new_features', leafCol="leafId")
evaluator = MulticlassClassificationEvaluator(labelCol='user_churn')

pipeline = Pipeline(stages=[dec_tree])
dec_tree_paramGrid = (ParamGridBuilder()
                .addGrid(dec_tree.maxDepth, [2, 3, 4,5])
                .addGrid(dec_tree.maxBins, [2, 10, 32])
                .build())


crossval = CrossValidator(
    estimator=pipeline,
    estimatorParamMaps=dec_tree_paramGrid,
    evaluator=evaluator,
    numFolds=3)

dec_tree_start = time.time()
dec_tree_model = crossval.fit(train)
dec_tree_end = time.time()

# %%
dec_tree_results = dec_tree_model.transform(test)
dec_tree_safe = evaluate_result(dec_tree_results, 'Decision Tree', dec_tree_start, dec_tree_end)

best_param = list(dec_tree.getEstimatorParamMaps()[np.argmax(dec_tree_model.avgMetrics)].values())
print(' Best maxDepth parameter is {}, Best maxBins parameter is {}.'.format(best_param[0],best_param[1]))

# %%
columns=['Model','Accuracy score','F-1 Score','Total training time']
spark.createDataFrame([log_reg,ran_forest,dec_tree_safe],columns).show()
